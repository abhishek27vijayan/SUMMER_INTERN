# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek27vijayan/SUMMER_INTERN/blob/main/classify_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import tree 
from sklearn import metrics
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
#from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"/content/trainingdata/files.txt", sep = "\t",header=None)
df
# Out:
#     0  1                        2
# 0   0  1  trainingdata/set0-1.txt
# 1   0  1  trainingdata/set0-2.txt
# 2   0  1  trainingdata/set0-3.txt
# 3   0  1  trainingdata/set0-4.txt
# 4   0  1  trainingdata/set0-5.txt
# 5   0  1  trainingdata/set0-6.txt
# 6   0  1  trainingdata/set0-7.txt
# 7   0  1  trainingdata/set0-8.txt
# 8   1  1  trainingdata/set1-1.txt
# 9   1  1  trainingdata/set1-2.txt
# 10  1  1  trainingdata/set1-3.txt
# 11  1  1  trainingdata/set1-4.txt
# 12  1  1  trainingdata/set1-5.txt
# 13  1  1  trainingdata/set1-6.txt
# 14  1  1  trainingdata/set1-7.txt
# 15  1  1  trainingdata/set1-8.txt

# %%
a = "a"
b = "b"
d1 = ""
d2 = ""
for i in range(0,8):
    d1 = a+str(i+1)
    d2 = b+str(i+1)
    exec(d1 + f' = pd.read_csv(df.iloc[{i},2], sep = "\t")')
    exec(d2 + f' = pd.read_csv(df.iloc[{i+8},2], sep = "\t")')
a1['S1']
# Out:
# 0       0.196676
# 1       0.183857
# 2       0.170122
# 3       0.155548
# 4       0.140212
#           ...
# 1995    0.244838
# 1996    0.237510
# 1997    0.228982
# 1998    0.219299
# 1999    0.208511
# Name: S1, Length: 2000, dtype: float64

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a1['T'],y=a1['S1'])
fig1.update_layout(title='SIGNAL set 0- 1')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b5c7c8bf-3290-46a5-9be6-32d0095f6b89" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5c7c8bf-3290-46a5-9be6-32d0095f6b89")) {
#                     Plotly.newPlot(
#                         'b5c7c8bf-3290-46a5-9be6-32d0095f6b89',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a2['T'],y=a2['S1'])
fig1.update_layout(title='SIGNAL set 0- 2')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a7fe7147-99cf-4029-ad6b-7b12409f6038" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7fe7147-99cf-4029-ad6b-7b12409f6038")) {
#                     Plotly.newPlot(
#                         'a7fe7147-99cf-4029-ad6b-7b12409f6038',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a3['T'],y=a3['S1'])
fig1.update_layout(title='SIGNAL set 0- 3')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8d075db5-7736-4fe2-b0b1-917196cfad2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d075db5-7736-4fe2-b0b1-917196cfad2b")) {
#                     Plotly.newPlot(
#                         '8d075db5-7736-4fe2-b0b1-917196cfad2b',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a4['T'],y=a4['S1'])
fig1.update_layout(title='SIGNAL set 0- 4')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e082c138-7c8a-444a-8d4f-0469c0721dcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e082c138-7c8a-444a-8d4f-0469c0721dcf")) {
#                     Plotly.newPlot(
#                         'e082c138-7c8a-444a-8d4f-0469c0721dcf',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a5['T'],y=a5['S1'])
fig1.update_layout(title='SIGNAL set 0- 5')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3a692317-a1ce-4f1b-8337-659274c83792" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a692317-a1ce-4f1b-8337-659274c83792")) {
#                     Plotly.newPlot(
#                         '3a692317-a1ce-4f1b-8337-659274c83792',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a6['T'],y=a6['S1'])
fig1.update_layout(title='SIGNAL set 0- 6')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7b82d214-4030-40b2-bb27-8cb636611142" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b82d214-4030-40b2-bb27-8cb636611142")) {
#                     Plotly.newPlot(
#                         '7b82d214-4030-40b2-bb27-8cb636611142',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a7['T'],y=a7['S1'])
fig1.update_layout(title='SIGNAL set 0- 7')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c48a9b9a-b62f-4d90-9048-deee08a883fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c48a9b9a-b62f-4d90-9048-deee08a883fd")) {
#                     Plotly.newPlot(
#                         'c48a9b9a-b62f-4d90-9048-deee08a883fd',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=a8['T'],y=a8['S1'])
fig1.update_layout(title='SIGNAL set 0- 8')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b0d8dcc-b698-4f26-aff0-81e26319c80d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b0d8dcc-b698-4f26-aff0-81e26319c80d")) {
#                     Plotly.newPlot(
#                         '0b0d8dcc-b698-4f26-aff0-81e26319c80d',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b1['T'],y=b1['S1'])
fig1.update_layout(title='SIGNAL set 1- 1')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c19f7a3c-e1b4-45c1-b8bd-226235b3f12b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c19f7a3c-e1b4-45c1-b8bd-226235b3f12b")) {
#                     Plotly.newPlot(
#                         'c19f7a3c-e1b4-45c1-b8bd-226235b3f12b',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b2['T'],y=b2['S1'])
fig1.update_layout(title='SIGNAL set 1- 2')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="95bdcad2-2c25-4ed1-b057-f3cdf483dad4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95bdcad2-2c25-4ed1-b057-f3cdf483dad4")) {
#                     Plotly.newPlot(
#                         '95bdcad2-2c25-4ed1-b057-f3cdf483dad4',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b3['T'],y=b3['S1'])
fig1.update_layout(title='SIGNAL set 1- 3')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="112a2f9f-940e-42bc-a80d-10a3f3ebddce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("112a2f9f-940e-42bc-a80d-10a3f3ebddce")) {
#                     Plotly.newPlot(
#                         '112a2f9f-940e-42bc-a80d-10a3f3ebddce',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b4['T'],y=b4['S1'])
fig1.update_layout(title='SIGNAL set 1- 4')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2e7b4469-688c-4b23-99f0-4344898a0ec1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e7b4469-688c-4b23-99f0-4344898a0ec1")) {
#                     Plotly.newPlot(
#                         '2e7b4469-688c-4b23-99f0-4344898a0ec1',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b5['T'],y=b5['S1'])
fig1.update_layout(title='SIGNAL set 1- 5')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2a2f1c38-0e51-4cb1-9e89-a1c130f33149" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a2f1c38-0e51-4cb1-9e89-a1c130f33149")) {
#                     Plotly.newPlot(
#                         '2a2f1c38-0e51-4cb1-9e89-a1c130f33149',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b6['T'],y=b6['S1'])
fig1.update_layout(title='SIGNAL set 1- 6')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1643f243-83c0-4701-ba39-d5cee61c825f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1643f243-83c0-4701-ba39-d5cee61c825f")) {
#                     Plotly.newPlot(
#                         '1643f243-83c0-4701-ba39-d5cee61c825f',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b7['T'],y=b7['S1'])
fig1.update_layout(title='SIGNAL set 1- 7')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a23c3165-a62a-48e0-9da1-8d3c0ecf196d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a23c3165-a62a-48e0-9da1-8d3c0ecf196d")) {
#                     Plotly.newPlot(
#                         'a23c3165-a62a-48e0-9da1-8d3c0ecf196d',
# ...

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=b8['T'],y=b8['S1'])
fig1.update_layout(title='SIGNAL set 1- 8')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5a228fe1-fc74-435a-8f6b-27f1aa68e9c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a228fe1-fc74-435a-8f6b-27f1aa68e9c5")) {
#                     Plotly.newPlot(
#                         '5a228fe1-fc74-435a-8f6b-27f1aa68e9c5',
# ...

# %%
Data1 = pd.DataFrame()
for i in range(1,8):
    exec(f'Data1 = pd.concat([Data1,a{i}],ignore_index=True)')
Data1['Class'] = 0
Data1
# Out:
#           T        S1  Class
# 0         0  0.196676      0
# 1         1  0.183857      0
# 2         2  0.170122      0
# 3         3  0.155548      0
# 4         4  0.140212      0
# ...     ...       ...    ...
# 13995  1995  0.258964      0
# 13996  1996  0.254841      0
# 13997  1997  0.249435      0
# 13998  1998  0.242775      0
# 13999  1999  0.234895      0
#
# [14000 rows x 3 columns]

# %%
Data2 = pd.DataFrame()
for i in range(8,9):
    exec(f'Data2 = pd.concat([Data2,a{i}],ignore_index=True)')
Data2['Class'] = 0
Data2
# Out:
#          T        S1  Class
# 0        0  0.168425      0
# 1        1  0.153803      0
# 2        2  0.138417      0
# 3        3  0.122351      0
# 4        4  0.105691      0
# ...    ...       ...    ...
# 1995  1995  0.227499      0
# 1996  1996  0.217774      0
# 1997  1997  0.206944      0
# 1998  1998  0.195067      0
# 1999  1999  0.182204      0
#
# [2000 rows x 3 columns]

# %%
Data3 = pd.DataFrame()
for i in range(1,8):
    exec(f'Data3 = pd.concat([Data3,b{i}],ignore_index=True)')
Data3['Class'] = 1
Data3
# Out:
#           T        S1  Class
# 0         0  0.251461      1
# 1         1  0.245027      1
# 2         2  0.237371      1
# 3         3  0.228534      1
# 4         4  0.218563      1
# ...     ...       ...    ...
# 13995  1995  0.225927      1
# 13996  1996  0.216022      1
# 13997  1997  0.205022      1
# 13998  1998  0.192982      1
# 13999  1999  0.179969      1
#
# [14000 rows x 3 columns]

# %%
Data4 = pd.DataFrame()
for i in range(8,9):
    exec(f'Data4 = pd.concat([Data4,b{i}],ignore_index=True)')
Data4['Class'] = 1
Data4
# Out:
#          T        S1  Class
# 0        0  0.211731      1
# 1        1  0.200141      1
# 2        2  0.187554      1
# 3        3  0.174038      1
# 4        4  0.159667      1
# ...    ...       ...    ...
# 1995  1995  0.252765      1
# 1996  1996  0.246969      1
# 1997  1997  0.239928      1
# 1998  1998  0.231678      1
# 1999  1999  0.222262      1
#
# [2000 rows x 3 columns]

# %%
Data = pd.concat([Data1,Data3],ignore_index=True)
Data
# Out:
#           T        S1  Class
# 0         0  0.196676      0
# 1         1  0.183857      0
# 2         2  0.170122      0
# 3         3  0.155548      0
# 4         4  0.140212      0
# ...     ...       ...    ...
# 27995  1995  0.225927      1
# 27996  1996  0.216022      1
# 27997  1997  0.205022      1
# 27998  1998  0.192982      1
# 27999  1999  0.179969      1
#
# [28000 rows x 3 columns]

# %%
Dataa = pd.concat([Data2,Data4],ignore_index=True)
Dataa
# Out:
#          T        S1  Class
# 0        0  0.168425      0
# 1        1  0.153803      0
# 2        2  0.138417      0
# 3        3  0.122351      0
# 4        4  0.105691      0
# ...    ...       ...    ...
# 3995  1995  0.252765      1
# 3996  1996  0.246969      1
# 3997  1997  0.239928      1
# 3998  1998  0.231678      1
# 3999  1999  0.222262      1
#
# [4000 rows x 3 columns]

# %%
# Split train and test data
train_features = Data.loc[0:27999]
train_labels = Data.loc[0:27999, 'Class']

test_features = Dataa.loc[0:3999]
test_labels = Dataa.loc[0:3999, 'Class']

# I want to use a T-days window of input data for predicting target_class
# It means I need to prepend (T-1) last train records to the 1st test window
T = 100 # my choice of the timesteps window

prepend_features = train_features.iloc[-(T-1):]
test_features = pd.concat([prepend_features, test_features], axis=0)

train_features.shape, train_labels.shape, test_features.shape, test_labels.shape
# Out:
# ((28000, 3), (28000,), (4099, 3), (4000,))

# %%
# Rescale the features
from sklearn.preprocessing import StandardScaler  # MinMaxScaler

scaler = StandardScaler()  # MinMaxScaler(feature_range=(-1,1))
scaled_train_features = pd.DataFrame(scaler.fit_transform(train_features.values),
                                     index=train_features.index,
                                     columns=train_features.columns)
# The Scaler is fit on the training set and then applied to the test set
scaled_test_features = pd.DataFrame(scaler.transform(test_features.values),
                                    index=test_features.index,
                                    columns=test_features.columns)

scaled_train_features.shape, scaled_test_features.shape
# Out:
# ((28000, 3), (4099, 3))

# %%
# Plot the rescaled_train_features
plt.style.use('fivethirtyeight')
scaled_train_features.plot(subplots=True,
                           layout=(6, 3),
                           figsize=(16,16),
                           fontsize=10, 
                           linewidth=2, 
                           title='Visualization of the scaled Train Features')
plt.show()

# %%
# Create sequences of T timesteps
X_train, y_train = [], []
for i in range(train_labels.shape[0] - (T-1)):
    X_train.append(scaled_train_features.iloc[i:i+T].values)
    y_train.append(train_labels.iloc[i + (T-1)])
X_train, y_train = np.array(X_train), np.array(y_train).reshape(-1,1)
print(f'Train data dimensions: {X_train.shape}, {y_train.shape}')

X_test, y_test = [], []
for i in range(test_labels.shape[0]):
    X_test.append(scaled_test_features.iloc[i:i+T].values)
    y_test.append(test_labels.iloc[i])
X_test, y_test = np.array(X_test), np.array(y_test).reshape(-1,1)  

print(f'Test data dimensions: {X_test.shape}, {y_test.shape}')
# Out:
# Train data dimensions: (27901, 100, 3), (27901, 1)
# Test data dimensions: (4000, 100, 3), (4000, 1)

# %%
# Import Keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, BatchNormalization,ConvLSTM2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.regularizers import l2
from time import time
from keras.layers import Dropout
from keras.layers import Flatten

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]
model = Sequential()
model.add(LSTM(100, input_shape=(n_timesteps,n_features)))
model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(Dense(n_outputs, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
History=model.fit(X_train, y_train, epochs=10, batch_size=2000,validation_split=0.0, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/10
# 14/14 [==============================] - 29s 2s/step - loss: 0.5267 - accuracy: 0.8712 - val_loss: 0.0545 - val_accuracy: 0.9902
# Epoch 2/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.0219 - accuracy: 0.9985 - val_loss: 0.3025 - val_accuracy: 0.9535
# Epoch 3/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.0103 - accuracy: 0.9977 - val_loss: 0.2818 - val_accuracy: 0.9720
# Epoch 4/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.2888 - val_accuracy: 0.9725
# Epoch 5/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.2883 - val_accuracy: 0.9725
# Epoch 6/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.2849 - val_accuracy: 0.9730
# Epoch 7/10
# ...

# %%
y_hat = model.predict_classes(X_test, batch_size=1999, verbose=1)
score = sum(y_hat == y_test) / len(y_test)
print(f'Prediction accuracy = {score*100}%')
#index = pd.date_range(start='1', end='1999')
#for i in range(y_hat.shape[0]):
 #   print( y_hat[i], y_test[i])
# Out:
# 3/3 [==============================] - 2s 346ms/step
# Prediction accuracy = [97.375]%

# %%
# Evaluate the model:
train_loss, train_acc = model.evaluate(X_train, y_train,batch_size=1999, verbose=1)
test_loss, test_acc = model.evaluate(X_test, y_test,batch_size=1999 , verbose=1)
print('-'*65)
print('-'*65)
print(f'train accuracy = {round(train_acc * 100, 4)}%')
print(f'test accuracy = {round(test_acc * 100, 4)}%')
print('-'*65)
print('-'*65)
# Out:
# 14/14 [==============================] - 10s 671ms/step - loss: 0.0013 - accuracy: 0.9997
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-f320f9e19c44> in <module>()
#       1 # Evaluate the model:
#       2 train_loss, train_acc = model.evaluate(X_train, y_train,batch_size=1999, verbose=1)
# ----> 3 test_loss, test_acc = model.evaluate(X_test, y_test,batch_size=1999 , verbose=1)
#       4 print('-'*65)
#       5 print('-'*65)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1439             use_multiprocessing=use_multiprocessing,
#    1440             model=self,
# -> 1441             steps_per_execution=self._steps_per_execution)
#    1442
# ...

# %%
# Plot the loss and accuracy curves over epochs:
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(18,6))
axs[0].plot(History.history['loss'], color='b', label='Training loss')
axs[0].plot(History.history['val_loss'], color='r', label='Validation loss')
axs[0].set_title("Loss curves")
axs[0].legend(loc='best', shadow=True)
axs[1].plot(History.history['accuracy'], color='b', label='Training accuracy')
axs[1].plot(History.history['val_accuracy'], color='r', label='Validation accuracy')
axs[1].set_title("Accuracy curves")
axs[1].legend(loc='best', shadow=True)
plt.show()

# %%
Test = pd.DataFrame()
Test1 = pd.DataFrame()
Test = pd.concat([Test,pd.read_csv(r"/content/testingdata/test1.txt", sep = "\t")],ignore_index=True)
Test
# Out:
#          T        S1
# 0        0  0.173212
# 1        1  0.158858
# 2        2  0.143715
# 3        3  0.127865
# 4        4  0.111393
# ...    ...       ...
# 1995  1995  0.230619
# 1996  1996  0.221265
# 1997  1997  0.210789
# 1998  1998  0.199247
# 1999  1999  0.186699
#
# [2000 rows x 2 columns]

# %%
test_features = Test.loc[0:1999]
prepend_features = train_features.iloc[-(T-1):]
test_features = pd.concat([prepend_features, test_features], axis=0)
scaled_test_features = pd.DataFrame(scaler.transform(test_features.values),
                                    index=test_features.index,
                                    columns=test_features.columns)
X_test= []
for i in range(2000):
    X_test.append(scaled_test_features.iloc[i:i+T].values)
   
X_test = np.array(X_test)  

print(f'Test data dimensions: {X_test.shape}')
# Out:
# Test data dimensions: (2000, 100, 3)

# %%
y_hat = model.predict_classes(X_test, batch_size=1999, verbose=1)
y_hat
# Out:
# 2/2 [==============================] - 1s 10ms/step
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int32)

# %%
#y_hat = model.predict(Test)

# %%
from scipy import stats
mode_info = stats.mode(y_hat )
print("class=",mode_info[0])
# Out:
# class= [[0]]

# %%
fig1=go.Figure(layout=dict(xaxis=dict(title="time"),yaxis=dict(title="amplitude")))
fig1.add_scatter(x=Test['T'],y=Test['S1'])
fig1.update_layout(title='SIGNAL test ')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e588ec5e-447b-496a-b7fa-373c3a005cac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e588ec5e-447b-496a-b7fa-373c3a005cac")) {
#                     Plotly.newPlot(
#                         'e588ec5e-447b-496a-b7fa-373c3a005cac',
# ...
